# %% [markdown]
# <a href="https://colab.research.google.com/github/nishant-harinkhede12/EDA-Projects/blob/main/All_Month.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

# %%
url = 'https://raw.githubusercontent.com/nishant-harinkhede12/EDA-Projects/main/All_Month.csv'

# %%
All_Month_data = pd.read_csv(url)

# %%
All_Month_data.head()
# Out:
#   Order ID  ... Month
# 0   176558  ...    04
# 1      NaN  ...   NaN
# 2   176559  ...    04
# 3   176560  ...    04
# 4   176560  ...    04
#
# [5 rows x 7 columns]

# %%
All_Month_data.isnull().sum()
# Out:
# Order ID            545
# Product             545
# Quantity Ordered    545
# Price Each          545
# Order Date          545
# Purchase Address    545
# Month               545
# dtype: int64

# %%
# Find NAN
nan_df = All_Month_data[All_Month_data.isna().any(axis=1)]
# display(nan_df.head())
nan_df
# Out:
#        Order ID Product Quantity Ordered  ... Order Date Purchase Address Month
# 1           NaN     NaN              NaN  ...        NaN              NaN   NaN
# 356         NaN     NaN              NaN  ...        NaN              NaN   NaN
# 735         NaN     NaN              NaN  ...        NaN              NaN   NaN
# 1433        NaN     NaN              NaN  ...        NaN              NaN   NaN
# 1553        NaN     NaN              NaN  ...        NaN              NaN   NaN
# ...         ...     ...              ...  ...        ...              ...   ...
# 185176      NaN     NaN              NaN  ...        NaN              NaN   NaN
# 185438      NaN     NaN              NaN  ...        NaN              NaN   NaN
# 186042      NaN     NaN              NaN  ...        NaN              NaN   NaN
# 186548      NaN     NaN              NaN  ...        NaN              NaN   NaN
# 186826      NaN     NaN              NaN  ...        NaN              NaN   NaN
#
# ...

# %%
All_Month_data = All_Month_data.dropna(how='all')
All_Month_data
# Out:
#        Order ID  ... Month
# 0        176558  ...    04
# 2        176559  ...    04
# 3        176560  ...    04
# 4        176560  ...    04
# 5        176561  ...    04
# ...         ...  ...   ...
# 186845   259353  ...    09
# 186846   259354  ...    09
# 186847   259355  ...    09
# 186848   259356  ...    09
# 186849   259357  ...    09
#
# [186305 rows x 7 columns]

# %%
All_Month_data['Order Date'].value_counts()
# Out:
# Order Date        355
# 12/15/19 20:16      8
# 04/02/19 13:24      7
# 10/30/19 21:28      7
# 12/11/19 13:24      7
#                  ...
# 12/31/19 21:40      1
# 10/18/19 20:53      1
# 04/16/19 10:44      1
# 08/01/19 16:23      1
# 11/19/19 21:20      1
# Name: Order Date, Length: 142396, dtype: int64

# %%
df_or = All_Month_data['Order Date'].str.find('Or')
df_or
# Out:
# 0        -1
# 2        -1
# 3        -1
# 4        -1
# 5        -1
#          ..
# 186845   -1
# 186846   -1
# 186847   -1
# 186848   -1
# 186849   -1
# Name: Order Date, Length: 185950, dtype: int64

# %%
df_orr = All_Month_data['Order Date'].str.contains('Or')
df_orr.sort_values()
df_orr.head()
# Out:
# 0    False
# 2    False
# 3    False
# 4    False
# 5    False
# Name: Order Date, dtype: bool

# %% [markdown]
# WE ARE ADDING A COLUMN AS 'MONTH'

# %%
All_Month_data['Month'] = All_Month_data['Order Date'].str[0:2]
All_Month_data
# Out:
#        Order ID  ... Month
# 0        176558  ...    04
# 2        176559  ...    04
# 3        176560  ...    04
# 4        176560  ...    04
# 5        176561  ...    04
# ...         ...  ...   ...
# 186845   259353  ...    09
# 186846   259354  ...    09
# 186847   259355  ...    09
# 186848   259356  ...    09
# 186849   259357  ...    09
#
# [186305 rows x 7 columns]

# %%
All_Month_data = All_Month_data[All_Month_data['Order Date'].str[0:2]!='Or']
All_Month_data
# Out:
#        Order ID  ... Month
# 0        176558  ...    04
# 2        176559  ...    04
# 3        176560  ...    04
# 4        176560  ...    04
# 5        176561  ...    04
# ...         ...  ...   ...
# 186845   259353  ...    09
# 186846   259354  ...    09
# 186847   259355  ...    09
# 186848   259356  ...    09
# 186849   259357  ...    09
#
# [185950 rows x 7 columns]

# %%
All_Month_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 185950 entries, 0 to 186849
# Data columns (total 7 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order ID          185950 non-null  object
#  1   Product           185950 non-null  object
#  2   Quantity Ordered  185950 non-null  object
#  3   Price Each        185950 non-null  object
#  4   Order Date        185950 non-null  object
#  5   Purchase Address  185950 non-null  object
#  6   Month             185950 non-null  object
# dtypes: object(7)
# memory usage: 11.3+ MB

# %%
All_Month_data['Month'] = All_Month_data['Month'].astype('int32')
All_Month_data
# Out:
#        Order ID  ... Month
# 0        176558  ...     4
# 2        176559  ...     4
# 3        176560  ...     4
# 4        176560  ...     4
# 5        176561  ...     4
# ...         ...  ...   ...
# 186845   259353  ...     9
# 186846   259354  ...     9
# 186847   259355  ...     9
# 186848   259356  ...     9
# 186849   259357  ...     9
#
# [185950 rows x 7 columns]

# %%
All_Month_data['Quantity Ordered'] = pd.to_numeric(All_Month_data['Quantity Ordered'])
All_Month_data['Price Each'] =pd.to_numeric(All_Month_data['Price Each'])
All_Month_data['Sales'] = All_Month_data['Quantity Ordered']*All_Month_data['Price Each']
All_Month_data
# Out:
#        Order ID                     Product  ...  Month   Sales
# 0        176558        USB-C Charging Cable  ...      4   23.90
# 2        176559  Bose SoundSport Headphones  ...      4   99.99
# 3        176560                Google Phone  ...      4  600.00
# 4        176560            Wired Headphones  ...      4   11.99
# 5        176561            Wired Headphones  ...      4   11.99
# ...         ...                         ...  ...    ...     ...
# 186845   259353      AAA Batteries (4-pack)  ...      9    8.97
# 186846   259354                      iPhone  ...      9  700.00
# 186847   259355                      iPhone  ...      9  700.00
# 186848   259356      34in Ultrawide Monitor  ...      9  379.99
# 186849   259357        USB-C Charging Cable  ...      9   11.95
#
# [185950 rows x 8 columns]

# %% [markdown]
# ADDING COLUMN 'CITY'

# %%
def get_city(address):
    return address.split(",")[1].strip(" ")

def get_state(address):
    return address.split(",")[2].split(" ")[1]

All_Month_data['City'] = All_Month_data['Purchase Address'].apply(lambda x: f"{get_city(x)}  ({get_state(x)})")
All_Month_data.head()
# Out:
#   Order ID                     Product  ...   Sales               City
# 0   176558        USB-C Charging Cable  ...   23.90       Dallas  (TX)
# 2   176559  Bose SoundSport Headphones  ...   99.99       Boston  (MA)
# 3   176560                Google Phone  ...  600.00  Los Angeles  (CA)
# 4   176560            Wired Headphones  ...   11.99  Los Angeles  (CA)
# 5   176561            Wired Headphones  ...   11.99  Los Angeles  (CA)
#
# [5 rows x 9 columns]

# %% [markdown]
# Question 1: What was the best month for sales? How much was earned that month?

# %%
All_Month_data['Sales'] = All_Month_data['Quantity Ordered'].astype('int') * All_Month_data['Price Each'].astype('float')

# %%
All_Month_data.groupby(['Month']).sum()
# Out:
#        Quantity Ordered    Price Each         Sales
# Month
# 1                 10903  1.811768e+06  1.822257e+06
# 2                 13449  2.188885e+06  2.202022e+06
# 3                 17005  2.791208e+06  2.807100e+06
# 4                 20558  3.367671e+06  3.390670e+06
# 5                 18667  3.135125e+06  3.152607e+06
# 6                 15253  2.562026e+06  2.577802e+06
# 7                 16072  2.632540e+06  2.647776e+06
# 8                 13448  2.230345e+06  2.244468e+06
# 9                 13109  2.084992e+06  2.097560e+06
# 10                22703  3.715555e+06  3.736727e+06
# 11                19798  3.180601e+06  3.199603e+06
# 12                28114  4.588415e+06  4.613443e+06

# %%
import matplotlib.pyplot as plt

months = range(1,13)
print(months)

plt.bar(months,All_Month_data.groupby(['Month']).sum()['Sales'])
plt.xticks(months)
plt.ylabel('Sales in USD ($)')
plt.xlabel('Month number')
plt.show()
# Out:
# range(1, 13)

# %% [markdown]
# Question 2: What city sold the most product?

# %%
All_Month_data.groupby(['City']).sum()
# Out:
#                      Quantity Ordered    Price Each   Month         Sales
# City
# Atlanta  (GA)                   16602  2.779908e+06  104794  2.795499e+06
# Austin  (TX)                    11153  1.809874e+06   69829  1.819582e+06
# Boston  (MA)                    22528  3.637410e+06  141112  3.661642e+06
# Dallas  (TX)                    16730  2.752628e+06  104620  2.767975e+06
# Los Angeles  (CA)               33289  5.421435e+06  208325  5.452571e+06
# New York City  (NY)             27932  4.635371e+06  175741  4.664317e+06
# Portland  (ME)                   2750  4.471893e+05   17144  4.497583e+05
# Portland  (OR)                  11303  1.860558e+06   70621  1.870732e+06
# San Francisco  (CA)             50239  8.211462e+06  315520  8.262204e+06
# Seattle  (WA)                   16553  2.733296e+06  104941  2.747755e+06

# %%
keys = [city for city, df in All_Month_data.groupby(['City'])]

plt.bar(keys,All_Month_data.groupby(['City']).sum()['Sales'])
plt.ylabel('Sales in USD ($)')
plt.xlabel('Month number')
plt.xticks(keys, rotation='vertical', size=8)
plt.show()

# %%
Question 3: What products are most often sold together?

# %%
df = All_Month_data[All_Month_data['Order ID'].duplicated(keep=False)]
df['Grouped'] = df.groupby('Order ID')['Product'].transform(lambda x: ','.join(x))
df2 = df[['Order ID', 'Grouped']].drop_duplicates()

# %%
from itertools import combinations
from collections import Counter

count = Counter()

for row in df2['Grouped']:
    row_list = row.split(',')
    count.update(Counter(combinations(row_list, 2)))

for key,value in count.most_common(10):
    print(key, value)
# Out:
# ('iPhone', 'Lightning Charging Cable') 1005
# ('Google Phone', 'USB-C Charging Cable') 987
# ('iPhone', 'Wired Headphones') 447
# ('Google Phone', 'Wired Headphones') 414
# ('Vareebadd Phone', 'USB-C Charging Cable') 361
# ('iPhone', 'Apple Airpods Headphones') 360
# ('Google Phone', 'Bose SoundSport Headphones') 220
# ('USB-C Charging Cable', 'Wired Headphones') 160
# ('Vareebadd Phone', 'Wired Headphones') 143
# ('Lightning Charging Cable', 'Wired Headphones') 92

# %%
product_group = All_Month_data.groupby('Product')
quantity_ordered = product_group.sum()['Quantity Ordered']

keys = [pair for pair, df in product_group]
plt.bar(keys, quantity_ordered)
plt.xticks(keys, rotation='vertical', size=8)
plt.show()
